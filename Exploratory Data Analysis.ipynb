# %% [markdown]
# # GRIP | THE SPARKS FOUNDATION.

# %% [markdown]
# ##  Data Science and Business Analytics (Batch: MAY_2021).

# %% [markdown]
# # TASK#3 : Exploratory Data Analysis - Retail Superstore.

# %% [markdown]
# ## Objective :

# %% [markdown]
# 1) Perform ‘Exploratory Data Analysis’ on Retail Superstore dataset.
# 2) As a business manager, try to find out the weak areas where you can
# work to make more profit.
# 3) Try to explore relationship between each factors and the Profit.

# %% [markdown]
# ### Import libraries :

# %%
import pandas as pd     #Import Pandas for data manipulation.
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Wrangling Stage :

# %% [markdown]
# ### =>Get the data and print first five rows :

# %%
dataset = pd.read_csv("SampleSuperstore.csv")

dataset.head()    #Print first five rows of the data.
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ### =>Print last five rows of the data :

# %%
dataset.tail()   #Print last five rows of the dataset.
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# ### =>Find some statistical measure to describe the nature of the dataset :

# %%
dataset.describe()    #Describe the dataset to get story from the dataset.
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### =>Find is there any NAN values in the dataset to tackle with :

# %%
dataset.isna().sum().sum()   #Sum all NAN values.bThere is no NaN value in the dataset.
# Out:
# 0

# %% [markdown]
# # Perform Data Visualizations :

# %% [markdown]
# ### => Pair Plot to have a glance visualization at the entire dataset :

# %%
sns.pairplot(data = dataset)    #It will plot each field with respect another.

# %% [markdown]
# ### =>Line Plot for Sales w.r.t Profit in view of 'Ship Mode' :

# %%
sns.lineplot(x = dataset["Sales"] , y = dataset["Profit"], hue = dataset["Category"], color = 'g')

# %% [markdown]
# ## *Analysis-1 :
# ### Through the Line Plot, we've found that, with increase in 'Sales' the 'Profit' is not clearly increasing. It is randomly moving up and down.

# %% [markdown]
# ### =>Bar Plot for 'Discount' w.r.t 'Sales' in view of 'Profit' :

# %%
sns.scatterplot(x = dataset["Discount"], y = dataset["Profit"], hue = dataset["Category"])

# %% [markdown]
# ## *Analysis-2 :
# ### After this analysis, we came to know that, the increase in 'Discount' means the decrease in 'Profit'. The problem may be because the more 'Discount' is given, which directly decreased the 'Profit'.

# %% [markdown]
# ### =>Count Plot to know the ratio of Sub-Categories w.r.t each other :

# %%
plot = sns.countplot(dataset["Sub-Category"])
plot.set_xticklabels(plot.get_xticklabels() , rotation = 90)
# Out:
# [Text(0, 0, 'Bookcases'),
#  Text(0, 0, 'Chairs'),
#  Text(0, 0, 'Labels'),
#  Text(0, 0, 'Tables'),
#  Text(0, 0, 'Storage'),
#  Text(0, 0, 'Furnishings'),
#  Text(0, 0, 'Art'),
#  Text(0, 0, 'Phones'),
#  Text(0, 0, 'Binders'),
#  Text(0, 0, 'Appliances'),
#  Text(0, 0, 'Paper'),
#  Text(0, 0, 'Accessories'),
#  Text(0, 0, 'Envelopes'),
#  Text(0, 0, 'Fasteners'),
#  Text(0, 0, 'Supplies'),
#  Text(0, 0, 'Machines'),
#  Text(0, 0, 'Copiers')]

# %% [markdown]
# ## *Analysis-3 :
# ### This Analysis shows that 'Binders' have highest Sales, then 'Papers' and then 'Furnishings'.

# %% [markdown]
# ### =>Bar Chart for Ship_Mode categories :

# %%
plot = sns.countplot(dataset["Ship Mode"])
plot.set_xticklabels(plot.get_xticklabels() , rotation = 40)
# Out:
# [Text(0, 0, 'Second Class'),
#  Text(0, 0, 'Standard Class'),
#  Text(0, 0, 'First Class'),
#  Text(0, 0, 'Same Day')]

# %% [markdown]
# ## *Analysis-4 :
# ### In the Ship Mode, the 'Standard Class' is preferred more than other modes.

# %% [markdown]
# ### =>Bar Chart for Segment categories :

# %%
plot = sns.countplot(dataset["Segment"])
plot.set_xticklabels(plot.get_xticklabels() , rotation = 10)
# Out:
# [Text(0, 0, 'Consumer'), Text(0, 0, 'Corporate'), Text(0, 0, 'Home Office')]

# %% [markdown]
# ## *Analysis-5 :
# ### The Sales related to 'Consumer' has more counts than 'Corporate' and 'Home Office'.

# %% [markdown]
# ### =>Bar Chart for 'Category' :

# %%
plot = sns.countplot(dataset["Category"])
plot.set_xticklabels(plot.get_xticklabels() , rotation = 10)
# Out:
# [Text(0, 0, 'Furniture'),
#  Text(0, 0, 'Office Supplies'),
#  Text(0, 0, 'Technology')]

# %% [markdown]
# ## *Analysis-6 :
# ### The 'Office Supplies' are more than 'Furniture' and 'Technology'. There is need to take steps to increase the Sales of 'Furniture' and 'Technology'.

# %% [markdown]
# ### =>Bar Chart for Region based Supplies :

# %%
plot = sns.countplot(dataset["Region"])
plot.set_xticklabels(plot.get_xticklabels() , rotation = 20)
# Out:
# [Text(0, 0, 'South'),
#  Text(0, 0, 'West'),
#  Text(0, 0, 'Central'),
#  Text(0, 0, 'East')]

# %% [markdown]
# ## *Analysis-7 :
# ### There are more orders from the 'West' and 'East ' of United States than 'South' and 'Central' areas. We should engage more on 'South' and 'Central' areas of The United States.

# %%
sns.barplot(x = dataset["Category"] , y = dataset["Discount"])

# %% [markdown]
# ## *Analysis-8 :
# ### We are giving more 'Discount' on 'Furniture' Supplies than other supplies.

# %% [markdown]
# ### => Strip Plot for 'Discount' vs 'Profit' in view of 'Category' of Supplies :

# %%
sns.stripplot(x = dataset["Profit"], y = dataset["Discount"], hue = dataset["Category"])

# %% [markdown]
# ## *Analysis-9 :
# ### If we increase the 'Discount' from 0.5, the 'Profit' decrease eventually.

# %% [markdown]
# # Conclusion :
#
# #### 1) Discount should be given thoughtfully, unnecessary discount witnesses low profit.
# #### 2) Discount on Furniute Supplies should be kept low, as we are facing more loss here.
# #### 3) We should concentrate on Technology Sales because we have low Sales in it.
# #### 4) The Sales at the South and Central part of United States is lower than other Regions. More work should be done there to increase the number of Sales.
# #### 5) People prefer 'Standard Class' ship mode more than other ship modes.
